# %% [markdown]
# # Module 3 : Data Visualization Process

# %%
#import libraries for access and functional purpose
import pandas as p
import numpy as n
import matplotlib.pyplot as plt
import seaborn as s

# %%
#read the given dataset
df = p.read_csv("df.csv")

# %%
df.rename(columns={'Mean Temp':'T'}, inplace=True)
df.rename(columns={'Average Humidity':'H'}, inplace=True)
df.rename(columns={'rainfall':'R'}, inplace=True)
df.rename(columns={'Cost of Cultivation (`/Hectare) C2':'CC'}, inplace=True)
df.rename(columns={'Cost of Production (`/Quintal) C2':'CP'}, inplace=True)
df.rename(columns={'Yield (Quintal/ Hectare) ':'Y'}, inplace=True)

# %%
df.rename(columns={'cost of production per yield':'CPPY'}, inplace=True)

# %%
df['CP'].hist(figsize=(7,6), color='orange', alpha=0.7)
plt.xlabel('Cost Production (per 100kg)')
plt.ylabel('No of counts')
plt.title('Cost Production per 100kg by counts')
# Out:
# Text(0.5,1,'Cost Production per 100kg by counts')

# %%
df.columns
# Out:
# Index(['State_Name', 'District_Name', 'Crop_Year', 'Season', 'Crop', 'Area',
#        'R', 'H', 'T', 'CC', 'CP', 'Y', 'CPPY'],
#       dtype='object')

# %%
df['CPPY'].hist(figsize=(7,6), color='black', alpha=0.7)
plt.xlabel('Cost Production of crop')
plt.ylabel('No of counts')
plt.title('Cost Production of crop by counts')
# Out:
# Text(0.5,1,'Cost Production of crop by counts')

# %%
# Heatmap plot diagram
fig, ax = plt.subplots(figsize=(15,10))
s.heatmap(df.corr(), ax=ax, annot=True)

# %%
df.columns
# Out:
# Index(['State_Name', 'District_Name', 'Crop_Year', 'Season', 'Crop', 'Area',
#        'R', 'H', 'T', 'CC', 'CP', 'Y', 'CPPY'],
#       dtype='object')

# %%
df.boxplot(column="CP", by="Season", figsize=(15,10))

# %%
df.boxplot(column="CPPY", by="Season", figsize=(15,10))

# %%
#Propagation by variable
def PropByVar(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(10,10), autopct='%1.2f%%', fontsize = 12)
    ax.set_title(variable + ' (in Percentage)', fontsize = 15)
    return n.round(dataframe_pie/df.shape[0]*100,2)

PropByVar(df, 'Crop')
# Out:
# Rice                     5.98
# Maize                    5.71
# Moong(Green Gram)        4.13
# Urad                     3.95
# Sesamum                  3.61
# Groundnut                3.53
# Sugarcane                3.25
# Wheat                    3.19
# Arhar/Tur                3.11
# Rapeseed &Mustard        3.06
# Gram                     3.01
# Jowar                    3.00
# Onion                    2.95
# Potato                   2.75
# Dry chillies             2.66
# Bajra                    2.30
# Sunflower                2.28
# Cotton(lint)             1.91
# Small millets            1.90
# Sweet potato             1.80
# Peas & beans (Pulses)    1.78
# Linseed                  1.77
# Barley                   1.70
# Ragi                     1.69
# Turmeric                 1.69
# Masoor                   1.63
# Horse-gram               1.55
# Other Kharif pulses      1.49
# Coriander                1.44
# Castor seed              1.44
#                          ...
# Ribed Guard              0.02
# Yam                      0.02
# Cashewnut Raw            0.01
# Rubber                   0.01
# Carrot                   0.01
# Lentil                   0.01
# Cashewnut Processed      0.01
# Atcanut (Raw)            0.01
# Bean                     0.01
# Arcanut (Processed)      0.01
# Jute & mesta             0.01
# Rajmash Kholar           0.01
# Cond-spcs other          0.01
# Beet Root                0.01
# Kapas                    0.01
# Peas  (vegetable)        0.00
# Colocosia                0.00
# Ber                      0.00
# other fibres             0.00
# Ricebean (nagadal)       0.00
# Perilla                  0.00
# Jobster                  0.00
# Turnip                   0.00
# Pear                     0.00
# Coffee                   0.00
# Plums                    0.00
# Litchi                   0.00
# Apple                    0.00
# Peach                    0.00
# Other Dry Fruit          0.00
# Name: Crop, Length: 124, dtype: float64

# %%
#Propagation by variable
def PropByVar(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(10,10), autopct='%1.2f%%', fontsize = 12)
    ax.set_title(variable + ' (in Percentage)', fontsize = 15)
    return n.round(dataframe_pie/df.shape[0]*100,2)


PropByVar(df, 'State_Name')
# Out:
# Uttar Pradesh                  14.24
# Madhya Pradesh                  9.81
# Karnataka                       9.03
# Bihar                           8.08
# Assam                           6.25
# Odisha                          5.80
# Tamil Nadu                      5.79
# Maharashtra                     5.40
# Rajasthan                       5.35
# Chhattisgarh                    4.58
# Andhra Pradesh                  4.12
# Gujarat                         3.61
# Haryana                         2.51
# Telangana                       2.42
# Kerala                          1.82
# Nagaland                        1.67
# Punjab                          1.36
# Meghalaya                       1.23
# Arunachal Pradesh               1.09
# Himachal Pradesh                1.07
# Uttarakhand                     0.98
# Jammu and Kashmir               0.70
# Tripura                         0.60
# Manipur                         0.54
# Jharkhand                       0.54
# Mizoram                         0.41
# Puducherry                      0.37
# Sikkim                          0.31
# Dadra and Nagar Haveli          0.11
# Goa                             0.09
# Andaman and Nicobar Islands     0.09
# Chandigarh                      0.04
# Name: State_Name, dtype: float64

# %%
#Propagation by variable
def PropByVar(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(10,10), autopct='%1.2f%%', fontsize = 12)
    ax.set_title(variable + ' (in Percentage)', fontsize = 15)
    return n.round(dataframe_pie/df.shape[0]*100,2)


PropByVar(df, 'CPPY')
# Out:
# 79151.4760     0.52
# 136507.3826    0.52
# 12944.0688     0.52
# 32026.7748     0.52
# 16114.1358     0.52
# 8860.4565      0.52
# 41484.6320     0.52
# 27286.1140     0.52
# 27671.0902     0.52
# 48737.8652     0.52
# 45325.8320     0.52
# 15106.6185     0.52
# 35865.0540     0.52
# 86529.0818     0.52
# 609974.0160    0.52
# 4488.0620      0.52
# 41259.5874     0.52
# 19003.1472     0.52
# 81299.7540     0.52
# 1267.8856      0.52
# 26996.0715     0.52
# 572768.6584    0.52
# 107556.6996    0.52
# 799076.6525    0.52
# 1389.9492      0.52
# 694141.3110    0.52
# 10648.2432     0.52
# 52363.9616     0.52
# 4841.0271      0.52
# 95132.4396     0.52
#                ...
# 38856.2058     0.25
# 13341.3160     0.25
# 80793.7874     0.25
# 24204.9760     0.25
# 23398.7940     0.25
# 14180.3010     0.25
# 16558.0240     0.25
# 61218.6561     0.25
# 22988.6616     0.25
# 26619.9220     0.25
# 38842.4517     0.25
# 17820.6360     0.25
# 2152.2704      0.25
# 51728.0552     0.25
# 5243.8400      0.25
# 62870.0160     0.25
# 4660.4100      0.25
# 16156.3850     0.25
# 361266.6720    0.25
# 84337.9992     0.25
# 2961.5625      0.25
# 1119.6982      0.25
# 759223.9064    0.25
# 518098.9536    0.25
# 996.0219       0.25
# 1459.5892      0.25
# 8573.3200      0.25
# 49104.6269     0.25
# 1621.0088      0.25
# 884.2152       0.25
# Name: CPPY, Length: 337, dtype: float64

# %%
#Propagation by variable
def PropByVar(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(10,10), autopct='%1.2f%%', fontsize = 12)
    ax.set_title(variable + ' (in Percentage)', fontsize = 15)
    return n.round(dataframe_pie/df.shape[0]*100,2)


PropByVar(df, 'Y')
# Out:
# 42.95      2.08
# 9.33       2.08
# 6.83       2.08
# 16.69      2.08
# 8.05       2.08
# 11.97      2.08
# 10.29      2.08
# 23.56      2.08
# 10.93      2.08
# 13.70      2.08
# 19.05      2.08
# 31.10      2.08
# 4.71       2.08
# 42.68      2.08
# 13.45      2.08
# 19.90      2.08
# 11.98      2.08
# 3.01       2.07
# 4.05       2.07
# 5.90       2.07
# 1.32       2.07
# 6.42       2.07
# 9.83       2.07
# 7.47       2.07
# 9.59       2.07
# 12.69      2.07
# 24.39      2.07
# 8.72       2.07
# 17.83      2.07
# 36.61      2.07
# 19.94      2.07
# 448.89     2.07
# 757.92     2.07
# 13.57      2.07
# 56.00      2.07
# 67.41      2.07
# 13.54      2.07
# 11.61      2.07
# 32.42      2.07
# 12.94      2.07
# 6.70       2.07
# 986.21     2.07
# 39.04      2.07
# 37.19      1.81
# 23.59      1.81
# 39.83      1.81
# 1015.45    1.81
# 744.01     1.81
# 34.99      1.81
# Name: Y, dtype: float64

# %%
count_classes = p.value_counts(df['State_Name'], sort = True).sort_index()
count_classes.plot(kind = 'bar', figsize=(20,15))
plt.title("Dataset by each states")
plt.xlabel("Number of States")
plt.ylabel("Given data counts")
# Out:
# Text(0,0.5,'Given data counts')

# %%
#Density Plots
plt = df.plot(kind= 'density', subplots=True, layout=(4,3), sharex=False, 
                     sharey=False,fontsize=12, figsize=(15,10))
